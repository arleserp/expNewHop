# %% [markdown]
# ***Test to correlate graph metric with failure***

# %%
# Linear - Line of best fit
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

url = 'https://gist.githubusercontent.com/seankross/a412dfbd88b3db70b74b/raw/5f23f993cd87c283ce766e7ac6b329ee7cc2e1d1/mtcars.csv'
df=pd.read_csv(url)
plt.rcParams.update({'figure.figsize':(10,8), 'figure.dpi':100})
sns.lmplot(x='mpg', y='disp', data=df)
plt.title("Scatter Plot with Linear fit");
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-12ed32fc9520> in <module>
#       7 df=pd.read_csv(url)
#       8 plt.rcParams.update({'figure.figsize':(10,8), 'figure.dpi':100})
# ----> 9 sns.lmplot(x='mpg', y='disp', data=df)
#      10 plt.title("Scatter Plot with Linear fit");
#
# NameError: name 'sns' is not defined

# %%
# Scatter Plot with lowess line fit

plt.title("Scatter Plot with Lowess fit");

# %%
import seaborn as sns
url = 'https://gist.githubusercontent.com/seankross/a412dfbd88b3db70b74b/raw/5f23f993cd87c283ce766e7ac6b329ee7cc2e1d1/mtcars.csv'
df=pd.read_csv(url)
#x1 = np.random.randn(100)
#y1 = np.random.randn(100)

plt.rcParams.update({'figure.figsize':(10,8), 'figure.dpi':100})
sns.jointplot(x='mpg', y='disp', data=df);

# %% [markdown]
# # Point byserial
#
# https://towardsdatascience.com/point-biserial-correlation-with-python-f7cd591bd3b1
#
# We can initially relate some node metric with point-biserial

# %%
import pandas as pd
from scipy.stats import pointbiserialr

# get data
df_nodes = pd.read_csv('ASNetw2h00625_net.csv', sep=';')

df_nodes.head(20)
# Out:
#        Id      state  simfailed  Degree  Weighted Degree  Eccentricity  \
# 0    4969  Recovered          0       5                5             6
# 1    2548  Recovered          0      21               21             5
# 2   10656     Failed          2       1                1             7
# 3    1335  Recovered          0       2                2             6
# 4    1455  Recovered          0       1                1             7
# 5    1334  Recovered          0       2                2             6
# 6    1453  Recovered          0       1                1             7
# 7   10771  Recovered          0       2                2             6
# 8    3999  Recovered          0       1                1             7
# 9    3758  Recovered          0       2                2             6
# 10   4738  Recovered          0       1                1             7
# 11   3527  Recovered          0       1                1             6
# 12      1  Recovered          0      67               67             5
# 13      3  Recovered          0       3                3             6
# 14   1225  Recovered          0      10               10             5
# 15   1103  Recovered          0       4                4             6
# 16      4     Failed          2       1                1             8
# 17   2554  Recovered          0       4                4             6
# 18      6  Recovered          0       1                1             6
# 19   2553  Recovered          0       3                3             7
#
#     closnesscentrality  harmonicclosnesscentrality  betweenesscentrality  \
# 0             0.315238                    0.335062            796.382134
# 1             0.404913                    0.443020           2745.559256
# 2             0.246503                    0.256313              0.000000
# 3             0.293678                    0.309263             81.417149
# 4             0.218283                    0.226377              0.000000
# 5             0.298481                    0.313731             37.588565
# 6             0.268947                    0.281167              0.000000
# 7             0.320980                    0.341455             94.780643
# 8             0.262320                    0.274401              0.000000
# 9             0.263538                    0.277071              1.033333
# 10            0.247578                    0.258140              0.000000
# 11            0.312921                    0.330267              0.000000
# 12            0.455031                    0.514481          12757.053456
# 13            0.340440                    0.364742             59.754483
# 14            0.376566                    0.407110           1205.045822
# 15            0.307646                    0.322766            175.691644
# 16            0.208827                    0.219539              0.000000
# 17            0.287563                    0.302707              2.635155
# 18            0.312921                    0.330267              0.000000
# 19            0.253850                    0.266247             86.477420
#
#     Authority       Hub  modularity_class  pageranks  componentnumber  \
# 0    0.017926  0.017926                 0   0.001917                0
# 1    0.129725  0.129726                 5   0.005764                0
# 2    0.000597  0.000597                 6   0.000856                0
# 3    0.008015  0.008015                 6   0.000898                0
# 4    0.000214  0.000214                 3   0.000639                0
# 5    0.008117  0.008117                 9   0.000847                0
# 6    0.003505  0.003504                 0   0.000566                0
# 7    0.013092  0.013092                 9   0.000904                0
# 8    0.001652  0.001652                 4   0.000561                0
# 9    0.002328  0.002328                 6   0.000811                0
# 10   0.000921  0.000921                 6   0.000548                0
# 11   0.011473  0.011473                 0   0.000502                0
# 12   0.247249  0.247248                 0   0.016502                0
# 13   0.025409  0.025409                 4   0.001005                0
# 14   0.053568  0.053569                 4   0.002845                0
# 15   0.005410  0.005410                 8   0.001382                0
# 16   0.000104  0.000104                 4   0.000807                0
# 17   0.008088  0.008088                 6   0.000636                0
# 18   0.011473  0.011473                 0   0.000502                0
# 19   0.001163  0.001163                10   0.001541                0
#
#     clustering  triangles  eigencentrality
# 0     0.100000          1         0.058677
# 1     0.300000         63         0.430063
# 2     0.000000          0         0.002702
# 3     0.000000          0         0.025818
# 4     0.000000          0         0.001743
# 5     0.000000          0         0.026429
# 6     0.000000          0         0.011557
# 7     0.000000          0         0.044096
# 8     0.000000          0         0.006463
# 9     0.000000          0         0.009098
# 10    0.000000          0         0.004028
# 11    0.000000          0         0.037492
# 12    0.109000        241         0.826409
# 13    0.666667          2         0.087223
# 14    0.200000          9         0.186706
# 15    0.000000          0         0.022350
# 16    0.000000          0         0.001355
# 17    0.333333          1         0.027841
# 18    0.000000          0         0.037492
# 19    0.000000          0         0.005459

# %%
# get continuous and dichotomous data
df_nodes['state'] = df_nodes['state'].map({
    'Recovered': 1,
    'Failed': 0
})
#df_nodes.set_index('Id', drop=True, inplace=True)
grades = df_nodes['Eccentricity']
question_1 = df_nodes['state']
# pbc of first question
pbc = pointbiserialr(question_1, grades)
print(pbc)
# Out:
# PointbiserialrResult(correlation=-0.38739703190705965, pvalue=8.850571669985062e-20)

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
sns.heatmap(np.abs(df_nodes.corr()), annot=True)
plt.show()

# %%
data['state'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-27327c24c066> in <module>
# ----> 1 data['state'].value_counts()
#
# NameError: name 'data' is not defined

# %%
for col in data.columns:
    try:
        data.groupby('state')[col].plot(kind='hist', title=col, alpha=0.3)
        plt.legend(loc='best', title='state')
        plt.show()
    except:
        continue
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-3db46933daeb> in <module>
# ----> 1 for col in data.columns:
#       2     try:
#       3         data.groupby('state')[col].plot(kind='hist', title=col, alpha=0.3)
#       4         plt.legend(loc='best', title='state')
#       5         plt.show()
#
# NameError: name 'data' is not defined
